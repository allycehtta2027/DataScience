# %% [markdown]
# # SEMANA EDA (Exploratory de Data Analysis)
#
# - Análise Exploratória de Dados
#
#  Problema

# %% [markdown]
# - Uma escola necessita trabalhar com filmes em seu planejamento pedagogico
# - Precisa visualizar as notas de diversos filmes em suas diversas categorias
# - Os filmes devem atravessar gerações: A escola trabalha desde a creche até o nível superior

# %% [markdown]
# AMBIENTAÇÃO

# %% [markdown]
# - Usaremos a Linguagem Python (multi, tip.din, ident, bibli, poo)

# %%
# um alô mundo para não perder o costume 
""" Crie um 
Hello EDAn"""
# Out:
# ' Crie um \nHello EDAn'

# %%
mensagem = "Hello Semana EDA"
print(f"{mensagem}")
msg_input = input('Digite a palavra da semana')
print(msg_input)
# Out:
# Hello Semana EDA
# llk

# %% [markdown]
# Competências
#
# - Importar pandas
# - User dados csv
# - Organizar pandas VS CODE
# - Renomear colunas
# - Contar os dados
# - Melhorar as necessidades
# - Gráficos pandas (plot), Matplolib, Scarborn

# %% [markdown]
# FERREAMENTAS e RECURSOS

# %% [markdown]
# - Jupiter(Visual Code, Anaconda, Jupiter. Google Colab, Azure e AWS)
# - Kaggle (Risco de Crédito):IA ML Superv. Regressão
# - TrendView
# - Movielens ( opção de 100 mil)
# - Python - lambda (Paradigma Funcional)
# - Bibliotecas (Numpy, Pandas, Matplolib e Seaborn)
# - Gráficos (barras, pizzas, dispersão, hostograma, boxplot etc. )
# - Youtube(população, amostra, frequência, mediana, quartis)
# - Estatística descritiva (frequências e medidas)

# %% [markdown]
# # Tipos de Variáveis

# %% [markdown]
# ## Python
# ![1_2oBaD14rFkYcRPSp8f9cFQ.webp](attachment:1_2oBaD14rFkYcRPSp8f9cFQ.webp)

# %% [markdown]
# ## Pandas

# %% [markdown]
# ![1_S49y7WM3HCTwFHT3oKW5UA.png](attachment:1_S49y7WM3HCTwFHT3oKW5UA.png)

# %% [markdown]
# ## MYSQL

# %% [markdown]
# ![Curso-MySQL-03-Criando-um-Banco-de-Dados-MySQL-14-2048.webp](attachment:Curso-MySQL-03-Criando-um-Banco-de-Dados-MySQL-14-2048.webp)

# %% [markdown]
# ## Estatística Descritiva
#
# ![tipos_variaveis.png](attachment:tipos_variaveis.png)

# %%
## importação do pandas
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df['movieId']
# Out:
# 0              1
# 1              3
# 2              6
# 3             47
# 4             50
#            ...
# 100831    166534
# 100832    168248
# 100833    168250
# 100834    168252
# 100835    170875
# Name: movieId, Length: 100836, dtype: int64

# %%
df['rating']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64

# %% [markdown]
# ## Renomear as colunas em português

# %%
df.columns = ['usuario_id', 'filme_id', 'avaliacao','tempo']

# %%
df.columns
# Out:
# Index(['usuario_id', 'filme_id', 'avaliacao', 'tempo'], dtype='object')

# %%
df['avaliacao']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# ## mostrando uma coluna

# %%
df.avaliacao
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# # o líder 360° solicitou a contagem de notas x qtdfilmes
# # o líder 360° pediu a media de todos as notas

# %% [markdown]
# # Média Todas as Notas

# %%
# sem sentido....
# df.mean()

# %% [markdown]
# # Média de todos os filmes

# %%
df.avaliacao.mean()
# Out:
# np.float64(3.501556983616962)

# %%
df.head(25)
# Out:
#     usuario_id  filme_id  avaliacao      tempo
# 0            1         1        4.0  964982703
# 1            1         3        4.0  964981247
# 2            1         6        4.0  964982224
# 3            1        47        5.0  964983815
# 4            1        50        5.0  964982931
# 5            1        70        3.0  964982400
# 6            1       101        5.0  964980868
# 7            1       110        4.0  964982176
# 8            1       151        5.0  964984041
# 9            1       157        5.0  964984100
# 10           1       163        5.0  964983650
# 11           1       216        5.0  964981208
# 12           1       223        3.0  964980985
# 13           1       231        5.0  964981179
# 14           1       235        4.0  964980908
# 15           1       260        5.0  964981680
# 16           1       296        3.0  964982967
# 17           1       316        3.0  964982310
# 18           1       333        5.0  964981179
# ...

# %% [markdown]
# # Buscando valores únicos

# %%
df.avaliacao.unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# # Contando histórias com histogramas

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...

# %%
df.avaliacao.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.avaliacao.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: avaliacao, dtype: float64

# %% [markdown]
# # Média Mediana (Q2 - Segundo Quartil.) Soma

# %%
print(f'imprima a media:" {df.avaliacao.mean()}')
# Out:
# imprima a media:" 3.501556983616962

# %%
print(f"imprimindo o 2° quartil (mediana/metade):{df.avaliacao.median()}")
# Out:
# imprimindo o 2° quartil (mediana/metade):3.5

# %%
print(f'imprimindo a soma:{df.avaliacao.sum()}')
# Out:
# imprimindo a soma:353083.0

# %%
df.avaliacao.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: avaliacao, dtype: float64

# %% [markdown]
# População
# - Todos os Alunos do Senai DF
# - Uma amostra dos alunos do Senai DF Taguatinga

# %% [markdown]
# # Boxplot

# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %% [markdown]
# DatDriven(Netflix. Spotily)
# Import seaborn

# %%
import seaborn as sns

# %%
notas = df.avaliacao

# %%
sns.boxplot(x=notas)
# Out:
# <Axes: xlabel='avaliacao'>

# %%
sns.boxplot(notas)
# Out:
# <Axes: ylabel='avaliacao'>

# %% [markdown]
# Conclusão:
# - Que tipo de informações podemos extrair
# - Conseguimos descobrir a metade (mediana)
# - Conseguimos demostrar usando graficos (histograma e bloxplot)
# - Ler os dados e apresentar esses dados

# %% [markdown]
# Exercicios
# -EX.1 ler o dataset movies.csv

# %%
# codigo

# %%
import pandas as pd
df_filmes = pd.read_csv('datasets/movies.csv')
df_filmes
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# Exercicio2
#  mostrar os 5 primeiros

# %%
# taca codigo aki
df_filmes.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# - Ex.3 renomear as colunas para ['filme_id, 'titulo', 'generos]

# %%
#codigo
df_filmes.columns = ['filme_id', 'titulo', 'generos']

# %% [markdown]
# ex.4 mostrar os 5 primeiros com col. renomeados

# %%
# taca codigo aki!
df_filmes.query("filme_id == 1").head()
# Out:
#    filme_id            titulo                                      generos
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
#codigo
df.head()
# Out:
#    usuario_id  filme_id  avaliacao      tempo
# 0           1         1        4.0  964982703
# 1           1         3        4.0  964981247
# 2           1         6        4.0  964982224
# 3           1        47        5.0  964983815
# 4           1        50        5.0  964982931

# %% [markdown]
# ## Desafio - mostrar as 5 primeiros avaliações apenas do toy story com as colunas renomeadas.(dica use df.query())

# %%
df_filmes.query("filme_id == 1").head()
# Out:
#    filme_id            titulo                                      generos
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
